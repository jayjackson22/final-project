# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#'resources/data_modified.csv'
import csv

rows = []
with open('resources/data_modified.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    row = next(reader, None)
    while row is not None:
        
        gameNum = row.pop('gameNum')
        player = row.pop('player')
        new_k1 = {f'player_{player}_{k}': row[k] for k in row}
        row = next(reader, None)
        row.pop('gameNum')
        player = row.pop('player')
        new_k2 = {f'player_{player}_{k}': row[k] for k in row}
        row = next(reader, None)
        row.pop('gameNum')
        player = row.pop('player')
        new_k3 = {f'player_{player}_{k}': row[k] for k in row}
        row = next(reader, None)
        row.pop('gameNum')
        player = row.pop('player')
        new_k4 = {f'player_{player}_{k}': row[k] for k in row}
        
       
        final = {'gameNum':gameNum,**new_k1,**new_k2,**new_k3,**new_k4}
        rows.append(final)
        row = next(reader, None)
        
print(len(rows))
# Out:
# 50

# %%
reshaped = pd.DataFrame(rows)
reshaped.columns
# Out:
# Index(['gameNum', 'player_1_points', 'player_1_win', 'player_1_me',
#        'player_1_2', 'player_1_3', 'player_1_4', 'player_1_5', 'player_1_6',
#        'player_1_7',
#        ...
#        'player_4_2_3_R', 'player_4_production', 'player_4_tradeGain',
#        'player_4_robberCardsGain', 'player_4_totalGain', 'player_4_tradeLoss',
#        'player_4_robberCardsLoss', 'player_4_tribute', 'player_4_totalLoss',
#        'player_4_totalAvailable'],
#       dtype='object', length=165)

# %%
# Pandas dummies convert to categorical
reshaped = pd.get_dummies(reshaped)

# Create list of column names
columns = []
for ea in reshaped.columns:
    columns.append(ea)
# Pop 0th
columns.pop(0)
# Out:
# 'gameNum_1'

# %%
reshaped = pd.DataFrame(rows)
reshaped.head()
# Out:
#   gameNum player_1_points player_1_win player_1_me player_1_2 player_1_3  \
# 0       1               5            0                      1          3
# 1       2              10            1                      1          6
# 2       3               5            0                      0          3
# 3       4               7            0                      1          6
# 4       5               8            0           1          1          3
#
#   player_1_4 player_1_5 player_1_6 player_1_7  ... player_4_2_3_R  \
# 0          5          8          7         10  ...              S
# 1          3          9         10          8  ...              S
# 2          3         10         10          4  ...              L
# 3          5         12         14         20  ...              O
# 4          7          9         12         14  ...              C
#
#   player_4_production player_4_tradeGain player_4_robberCardsGain  \
# 0                  42                 12                        0
# 1                  61                 16                       11
# 2                  53                  2                        2
# 3                  75                 11                        8
# 4                  48                  4                        5
#
#   player_4_totalGain player_4_tradeLoss player_4_robberCardsLoss  \
# 0                 54                 24                        6
# 1                 88                 25                        6
# 2                 57                  4                        4
# 3                 94                 37                       19
# 4                 57                  6                       10
#
#   player_4_tribute player_4_totalLoss player_4_totalAvailable
# 0                0                 30                      24
# 1                4                 35                      53
# 2                8                 16                      41
# 3                0                 56                      38
# 4                9                 25                      32
#
# [5 rows x 165 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Assign X (data) and y (target)
X = reshaped[columns]
y = reshaped['gameNum_1']
print(X.shape, y.shape)
# Out:
# (50, 1855) (50,)

# %%
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X, y)
rf.score(X,y)
# Out:
# 1.0

# %%
importances = rf.feature_importances_
importances
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
sorted(zip(rf.feature_importances_, X), reverse=True)
# Out:
# [(0.0492237808129281, 'player_2_totalGain_62'),
#  (0.047826197937528965, 'player_4_production_42'),
#  (0.046511627906976744, 'player_2_production_48'),
#  (0.04023624953857512, 'player_1_totalAvailable_29'),
#  (0.030088451600079506, 'player_3_robberCardsGain_9'),
#  (0.029847597953910246, 'player_3_1_3_N_12'),
#  (0.02789942615524011, 'player_1_totalGain_45'),
#  (0.02448982972238787, 'player_2_totalAvailable_42'),
#  (0.023015213837472973, 'player_4_tradeLoss_24'),
#  (0.021064045773348097, 'player_3_totalLoss_28'),
#  (0.01777319097303208, 'player_4_7_10'),
#  (0.015897002642572967, 'player_3_9_7'),
#  (0.015634358642021878, 'player_4_2_2_N_8'),
#  (0.015503875968992248, 'player_2_robberCardsLoss_1'),
#  (0.015421478668986972, 'player_3_production_44'),
#  (0.015345673152982124, 'player_3_tradeLoss_24'),
#  (0.014532058670644337, 'player_3_tradeGain_14'),
#  (0.01408005062490112, 'player_2_9_7'),
#  (0.01408005062490112, 'player_1_totalLoss_16'),
#  (0.01335786998162413, 'player_3_6_7'),
#  (0.013249485840847963, 'player_2_2_1_N_4'),
#  (0.01170188144163781, 'player_3_7_10'),
#  (0.011434989844580844, 'player_4_totalAvailable_24'),
#  (0.011102761518043913, 'player_2_2_2_N_5'),
#  (0.01099289845137021, 'player_1_1_2_N_3'),
#  (0.010965432684701792, 'player_3_1_2_R_S'),
#  (0.010748203439233339, 'player_4_points_5'),
#  (0.010546854400674995, 'player_1_7_10'),
#  (0.010388651584664873, 'player_4_robberCardsLoss_6'),
#  (0.01023044876865475, 'player_4_totalGain_54'),
#  (0.0100359911406423, 'player_4_8_6'),
#  (0.009543756835393408, 'player_4_11_4'),
#  (0.009520662932899918, 'player_1_2_2_R_W'),
#  (0.009056550213686008, 'player_4_9_7'),
#  (0.008914634462453793, 'player_1_1_3_P_2'),
#  (0.008898908400569528, 'player_3_11_4'),
#  (0.008857160435233527, 'player_2_tradeLoss_11'),
#  (0.008857160435233527, 'player_1_production_38'),
#  (0.007910140800506248, 'player_2_robberCardsGain_6'),
#  (0.007751937984496124, 'player_3_2_1_N_8'),
#  (0.007751937984496124, 'player_2_totalLoss_20'),
#  (0.00758714338448558, 'player_1_1_1_R_L'),
#  (0.0074706885338114565, 'player_3_points_10'),
#  (0.0074223487844750306, 'player_3_8_6'),
#  (0.0070655684754522, 'player_3_4_5'),
#  (0.006931751753975549, 'player_1_tradeGain_5'),
#  (0.006921373200442967, 'player_4_2_2_P_5'),
#  (0.006729112833763999, 'player_1_4_5'),
#  (0.0065917840004218724, 'player_1_tradeLoss_10'),
#  (0.0065917840004218724, 'player_1_12_0'),
#  (0.006459948320413437, 'player_1_2_1_N_9'),
#  (0.006328112640404996, 'player_4_1_1_R_O'),
#  (0.006280505311513065, 'player_3_totalGain_67'),
#  (0.006280505311513065, 'player_1_1_3_R_C'),
#  (0.006142943435302238, 'player_2_2_3_R_O'),
#  (0.005939197384380106, 'player_1_robberCardsLoss_2'),
#  (0.005932605600379685, 'player_4_4_5'),
#  (0.005733204134366924, 'player_3_10_3'),
#  (0.005273427200337497, 'player_4_robberCardsGain_0'),
#  (0.005273427200337497, 'player_4_2_2_R_W'),
#  (0.005273427200337497, 'player_4_1_3_N_3'),
#  (0.005273427200337497, 'player_3_5_8'),
#  (0.005273427200337497, 'player_2_tradeLoss_15'),
#  (0.005273427200337497, 'player_1_totalLoss_20'),
#  (0.005273427200337497, 'player_1_1_3_P_3'),
#  (0.0052669917432303665, 'player_2_5_8'),
#  (0.0050602928509905255, 'player_1_5_8'),
#  (0.004681121971314085, 'player_1_2_2_P_3'),
#  (0.004515971293379933, 'player_4_2_3_P_3'),
#  (0.004429678848283501, 'player_4_6_7'),
#  (0.004291251384274642, 'player_2_2_1'),
#  (0.004037467700258399, 'player_3_totalAvailable_77'),
#  (0.004037467700258399, 'player_3_5_7'),
#  (0.004037467700258399, 'player_3_2_3_N_3'),
#  (0.003955070400253124, 'player_4_2_3_N_11'),
#  (0.003955070400253124, 'player_4_11_0'),
#  (0.003955070400253124, 'player_3_robberCardsLoss_4'),
#  (0.003955070400253124, 'player_3_3_2'),
#  (0.003955070400253124, 'player_3_1_3_R_W'),
#  (0.003955070400253124, 'player_2_tribute_0'),
#  (0.003955070400253124, 'player_2_1_3_P_2'),
#  (0.003955070400253124, 'player_1_2_3_N_11'),
#  (0.0037968675842430005, 'player_3_totalAvailable_39'),
#  (0.003714470284237725, 'player_4_totalLoss_30'),
#  (0.0032431577282075676, 'player_1_2_3_R_O'),
#  (0.002979486368190691, 'player_1_6_7'),
#  (0.0029363401456424703, 'player_1_5_9'),
#  (0.0029069767441860456, 'player_3_2_2_N_4'),
#  (0.002691645133505599, 'player_4_totalAvailable_23'),
#  (0.002691645133505599, 'player_4_6_5'),
#  (0.002691645133505599, 'player_3_robberCardsGain_2'),
#  (0.002691645133505599, 'player_3_2_2_N_9'),
#  (0.002691645133505599, 'player_3_1_1_N_8'),
#  (0.002597723899059872, 'player_2_4_5'),
#  (0.0024785107841586267, 'player_4_tradeGain_12'),
#  (0.0024785107841586267, 'player_3_1_3_P_1'),
#  (0.0024785107841586267, 'player_2_7_10'),
#  (0.002056636608131629, 'player_1_2_1_R_L'),
#  (0.0019841269841269823, 'player_1_1_2_R_C'),
#  (0.0019792182088075212, 'player_2_1_2_R_O'),
#  (0.0019792182088075212, 'player_1_10_3'),
#  (0.001977535200126562, 'player_1_production_31'),
#  (0.0018456995201181264, 'player_1_2_1'),
#  (0.0016049561044505427, 'player_4_2_3_P_2'),
#  (0.0014831514000949212, 'player_4_2_1_P_3'),
#  (0.0014714326729830599, 'player_4_3_3'),
#  (0.0014238253440911283, 'player_4_10_3'),
#  (0.001291989664082687, 'player_1_1_1_N_6'),
#  (0.0011601539840742517, 'player_2_tribute_8'),
#  (0.0011601539840742517, 'player_1_1_3_N_11'),
#  (0.0011376643680728136, 'player_2_me_1'),
#  (0.0010228251507321253, 'player_4_2_1_N_4'),
#  (0.000988767600063285, 'player_1_2_1_P_4'),
#  (0.000988767600063281, 'player_4_tribute_9'),
#  (0.0009718172983479113, 'player_4_1_3_R_L'),
#  (0.0009193003379049872, 'player_3_win_0'),
#  (0.0008579219903790167, 'player_4_1_1_P_5'),
#  (0.0008305647840531586, 'player_4_5_8'),
#  (0.0008305647840531583, 'player_2_10_3'),
#  (0.0007536606373815646, 'player_3_3_3'),
#  (0.0007422068283028215, 'player_2_2_1_P_5'),
#  (0.000727293501379879, 'player_3_2_1_P_5'),
#  (0.0007207017173794609, 'player_1_points_5'),
#  (0.0006863695090439258, 'player_1_1_3_N_10'),
#  (0.0005609008931268083, 'player_2_2_2_R_S'),
#  (0.00037917087967644027, 'player_2_1_3_N_10'),
#  (0.00020134903855833946, 'player_1_1_1_P_4'),
#  (0.0001979661582062184, 'player_3_1_2_P_3'),
#  (0.00017138638401096646, 'player_1_1_2_P_5'),
#  (0.00012561010623025762, 'player_4_1_2_P_3'),
#  (8.898908400569777e-05, 'player_4_2_1_P_4'),
#  (0.0, 'player_4_win_1'),
#  (0.0, 'player_4_win_0'),
#  (0.0, 'player_4_tribute_8'),
#  (0.0, 'player_4_tribute_6'),
#  (0.0, 'player_4_tribute_5'),
#  (0.0, 'player_4_tribute_4'),
#  (0.0, 'player_4_tribute_33'),
#  (0.0, 'player_4_tribute_24'),
#  (0.0, 'player_4_tribute_18'),
#  (0.0, 'player_4_tribute_14'),
#  (0.0, 'player_4_tribute_13'),
#  (0.0, 'player_4_tribute_12'),
#  (0.0, 'player_4_tribute_11'),
#  (0.0, 'player_4_tribute_10'),
#  (0.0, 'player_4_tribute_0'),
#  (0.0, 'player_4_tradeLoss_9'),
#  (0.0, 'player_4_tradeLoss_8'),
#  (0.0, 'player_4_tradeLoss_6'),
#  (0.0, 'player_4_tradeLoss_5'),
#  (0.0, 'player_4_tradeLoss_45'),
#  (0.0, 'player_4_tradeLoss_42'),
#  (0.0, 'player_4_tradeLoss_4'),
#  (0.0, 'player_4_tradeLoss_37'),
#  (0.0, 'player_4_tradeLoss_33'),
#  (0.0, 'player_4_tradeLoss_32'),
#  (0.0, 'player_4_tradeLoss_3'),
#  (0.0, 'player_4_tradeLoss_29'),
#  (0.0, 'player_4_tradeLoss_28'),
#  (0.0, 'player_4_tradeLoss_27'),
#  (0.0, 'player_4_tradeLoss_25'),
#  (0.0, 'player_4_tradeLoss_22'),
#  (0.0, 'player_4_tradeLoss_21'),
#  (0.0, 'player_4_tradeLoss_20'),
#  (0.0, 'player_4_tradeLoss_2'),
#  (0.0, 'player_4_tradeLoss_19'),
#  (0.0, 'player_4_tradeLoss_18'),
#  (0.0, 'player_4_tradeLoss_17'),
#  (0.0, 'player_4_tradeLoss_16'),
#  (0.0, 'player_4_tradeLoss_15'),
#  (0.0, 'player_4_tradeLoss_14'),
#  (0.0, 'player_4_tradeLoss_13'),
#  (0.0, 'player_4_tradeLoss_12'),
#  (0.0, 'player_4_tradeLoss_11'),
#  (0.0, 'player_4_tradeLoss_10'),
#  (0.0, 'player_4_tradeGain_9'),
#  (0.0, 'player_4_tradeGain_8'),
#  (0.0, 'player_4_tradeGain_7'),
#  (0.0, 'player_4_tradeGain_6'),
#  (0.0, 'player_4_tradeGain_5'),
#  (0.0, 'player_4_tradeGain_4'),
#  (0.0, 'player_4_tradeGain_3'),
#  (0.0, 'player_4_tradeGain_2'),
#  (0.0, 'player_4_tradeGain_19'),
#  (0.0, 'player_4_tradeGain_18'),
#  (0.0, 'player_4_tradeGain_17'),
#  (0.0, 'player_4_tradeGain_16'),
#  (0.0, 'player_4_tradeGain_15'),
#  (0.0, 'player_4_tradeGain_14'),
#  (0.0, 'player_4_tradeGain_13'),
#  (0.0, 'player_4_tradeGain_11'),
#  (0.0, 'player_4_tradeGain_10'),
#  (0.0, 'player_4_tradeGain_1'),
#  (0.0, 'player_4_totalLoss_7'),
#  (0.0, 'player_4_totalLoss_62'),
#  (0.0, 'player_4_totalLoss_56'),
#  (0.0, 'player_4_totalLoss_54'),
#  (0.0, 'player_4_totalLoss_50'),
#  (0.0, 'player_4_totalLoss_48'),
#  (0.0, 'player_4_totalLoss_45'),
#  (0.0, 'player_4_totalLoss_44'),
#  (0.0, 'player_4_totalLoss_40'),
#  (0.0, 'player_4_totalLoss_39'),
#  (0.0, 'player_4_totalLoss_38'),
#  (0.0, 'player_4_totalLoss_37'),
#  (0.0, 'player_4_totalLoss_35'),
#  (0.0, 'player_4_totalLoss_33'),
#  (0.0, 'player_4_totalLoss_32'),
#  (0.0, 'player_4_totalLoss_29'),
#  (0.0, 'player_4_totalLoss_27'),
#  (0.0, 'player_4_totalLoss_26'),
#  (0.0, 'player_4_totalLoss_25'),
#  (0.0, 'player_4_totalLoss_24'),
#  (0.0, 'player_4_totalLoss_23'),
#  (0.0, 'player_4_totalLoss_22'),
#  (0.0, 'player_4_totalLoss_21'),
#  (0.0, 'player_4_totalLoss_20'),
#  (0.0, 'player_4_totalLoss_19'),
#  (0.0, 'player_4_totalLoss_18'),
#  (0.0, 'player_4_totalLoss_16'),
#  (0.0, 'player_4_totalLoss_15'),
#  (0.0, 'player_4_totalLoss_14'),
#  (0.0, 'player_4_totalLoss_13'),
#  (0.0, 'player_4_totalLoss_10'),
#  (0.0, 'player_4_totalGain_97'),
#  (0.0, 'player_4_totalGain_94'),
#  (0.0, 'player_4_totalGain_93'),
#  (0.0, 'player_4_totalGain_90'),
#  (0.0, 'player_4_totalGain_88'),
#  (0.0, 'player_4_totalGain_87'),
#  (0.0, 'player_4_totalGain_83'),
#  (0.0, 'player_4_totalGain_80'),
#  (0.0, 'player_4_totalGain_79'),
#  (0.0, 'player_4_totalGain_77'),
#  (0.0, 'player_4_totalGain_74'),
#  (0.0, 'player_4_totalGain_73'),
#  (0.0, 'player_4_totalGain_72'),
#  (0.0, 'player_4_totalGain_70'),
#  (0.0, 'player_4_totalGain_66'),
#  (0.0, 'player_4_totalGain_65'),
#  (0.0, 'player_4_totalGain_63'),
#  (0.0, 'player_4_totalGain_61'),
#  (0.0, 'player_4_totalGain_60'),
#  (0.0, 'player_4_totalGain_57'),
#  (0.0, 'player_4_totalGain_53'),
#  (0.0, 'player_4_totalGain_50'),
#  (0.0, 'player_4_totalGain_49'),
#  (0.0, 'player_4_totalGain_48'),
#  (0.0, 'player_4_totalGain_47'),
#  (0.0, 'player_4_totalGain_44'),
#  (0.0, 'player_4_totalGain_40'),
#  (0.0, 'player_4_totalGain_39'),
#  (0.0, 'player_4_totalGain_38'),
#  (0.0, 'player_4_totalGain_35'),
#  (0.0, 'player_4_totalGain_34'),
#  (0.0, 'player_4_totalGain_108'),
#  (0.0, 'player_4_totalGain_107'),
#  (0.0, 'player_4_totalGain_105'),
#  (0.0, 'player_4_totalAvailable_70'),
#  (0.0, 'player_4_totalAvailable_55'),
#  (0.0, 'player_4_totalAvailable_53'),
#  (0.0, 'player_4_totalAvailable_52'),
#  (0.0, 'player_4_totalAvailable_51'),
#  (0.0, 'player_4_totalAvailable_49'),
#  (0.0, 'player_4_totalAvailable_48'),
#  (0.0, 'player_4_totalAvailable_47'),
#  (0.0, 'player_4_totalAvailable_46'),
#  (0.0, 'player_4_totalAvailable_45'),
#  (0.0, 'player_4_totalAvailable_44'),
#  (0.0, 'player_4_totalAvailable_43'),
#  (0.0, 'player_4_totalAvailable_42'),
#  (0.0, 'player_4_totalAvailable_41'),
#  (0.0, 'player_4_totalAvailable_40'),
#  (0.0, 'player_4_totalAvailable_39'),
#  (0.0, 'player_4_totalAvailable_38'),
#  (0.0, 'player_4_totalAvailable_37'),
#  (0.0, 'player_4_totalAvailable_35'),
#  (0.0, 'player_4_totalAvailable_34'),
#  (0.0, 'player_4_totalAvailable_33'),
#  (0.0, 'player_4_totalAvailable_32'),
#  (0.0, 'player_4_totalAvailable_31'),
#  (0.0, 'player_4_totalAvailable_30'),
#  (0.0, 'player_4_totalAvailable_27'),
#  (0.0, 'player_4_totalAvailable_26'),
#  (0.0, 'player_4_totalAvailable_25'),
#  (0.0, 'player_4_totalAvailable_22'),
#  (0.0, 'player_4_totalAvailable_21'),
#  (0.0, 'player_4_robberCardsLoss_9'),
#  (0.0, 'player_4_robberCardsLoss_8'),
#  (0.0, 'player_4_robberCardsLoss_7'),
#  (0.0, 'player_4_robberCardsLoss_5'),
#  (0.0, 'player_4_robberCardsLoss_4'),
#  (0.0, 'player_4_robberCardsLoss_3'),
#  (0.0, 'player_4_robberCardsLoss_2'),
#  (0.0, 'player_4_robberCardsLoss_19'),
#  (0.0, 'player_4_robberCardsLoss_15'),
#  (0.0, 'player_4_robberCardsLoss_12'),
#  (0.0, 'player_4_robberCardsLoss_11'),
#  (0.0, 'player_4_robberCardsLoss_10'),
#  (0.0, 'player_4_robberCardsLoss_1'),
#  (0.0, 'player_4_robberCardsLoss_0'),
#  (0.0, 'player_4_robberCardsGain_9'),
#  (0.0, 'player_4_robberCardsGain_8'),
#  (0.0, 'player_4_robberCardsGain_7'),
#  (0.0, 'player_4_robberCardsGain_6'),
#  (0.0, 'player_4_robberCardsGain_5'),
#  (0.0, 'player_4_robberCardsGain_4'),
#  (0.0, 'player_4_robberCardsGain_3'),
#  (0.0, 'player_4_robberCardsGain_2'),
#  (0.0, 'player_4_robberCardsGain_17'),
#  (0.0, 'player_4_robberCardsGain_15'),
#  (0.0, 'player_4_robberCardsGain_14'),
#  (0.0, 'player_4_robberCardsGain_11'),
#  (0.0, 'player_4_robberCardsGain_1'),
#  (0.0, 'player_4_production_87'),
#  (0.0, 'player_4_production_84'),
#  (0.0, 'player_4_production_82'),
#  (0.0, 'player_4_production_75'),
#  (0.0, 'player_4_production_73'),
#  (0.0, 'player_4_production_70'),
#  (0.0, 'player_4_production_68'),
#  (0.0, 'player_4_production_67'),
#  (0.0, 'player_4_production_63'),
#  (0.0, 'player_4_production_62'),
#  (0.0, 'player_4_production_61'),
#  (0.0, 'player_4_production_60'),
#  (0.0, 'player_4_production_59'),
#  (0.0, 'player_4_production_57'),
#  (0.0, 'player_4_production_56'),
#  (0.0, 'player_4_production_55'),
#  (0.0, 'player_4_production_54'),
#  (0.0, 'player_4_production_53'),
#  (0.0, 'player_4_production_51'),
#  (0.0, 'player_4_production_48'),
#  (0.0, 'player_4_production_47'),
#  (0.0, 'player_4_production_46'),
#  (0.0, 'player_4_production_43'),
#  (0.0, 'player_4_production_41'),
#  (0.0, 'player_4_production_40'),
#  (0.0, 'player_4_production_39'),
#  (0.0, 'player_4_production_38'),
#  (0.0, 'player_4_production_37'),
#  (0.0, 'player_4_production_35'),
#  (0.0, 'player_4_production_31'),
#  (0.0, 'player_4_production_30'),
#  (0.0, 'player_4_production_28'),
#  (0.0, 'player_4_production_23'),
#  (0.0, 'player_4_points_9'),
#  (0.0, 'player_4_points_8'),
#  (0.0, 'player_4_points_7'),
#  (0.0, 'player_4_points_6'),
#  (0.0, 'player_4_points_4'),
#  (0.0, 'player_4_points_2'),
#  (0.0, 'player_4_points_10'),
#  (0.0, 'player_4_me_1'),
#  (0.0, 'player_4_me_'),
#  (0.0, 'player_4_9_9'),
#  (0.0, 'player_4_9_8'),
#  (0.0, 'player_4_9_6'),
#  (0.0, 'player_4_9_5'),
#  (0.0, 'player_4_9_4'),
#  (0.0, 'player_4_9_3'),
#  (0.0, 'player_4_9_15'),
#  (0.0, 'player_4_9_14'),
#  (0.0, 'player_4_9_11'),
#  (0.0, 'player_4_9_10'),
#  (0.0, 'player_4_8_9'),
#  (0.0, 'player_4_8_8'),
#  (0.0, 'player_4_8_7'),
#  (0.0, 'player_4_8_5'),
#  (0.0, 'player_4_8_4'),
#  (0.0, 'player_4_8_18'),
#  (0.0, 'player_4_8_16'),
#  (0.0, 'player_4_8_14'),
#  (0.0, 'player_4_8_13'),
#  (0.0, 'player_4_8_12'),
#  (0.0, 'player_4_8_11'),
#  (0.0, 'player_4_8_10'),
#  (0.0, 'player_4_7_9'),
#  (0.0, 'player_4_7_8'),
#  (0.0, 'player_4_7_7'),
#  (0.0, 'player_4_7_6'),
#  (0.0, 'player_4_7_5'),
#  (0.0, 'player_4_7_4'),
#  (0.0, 'player_4_7_23'),
#  (0.0, 'player_4_7_20'),
#  (0.0, 'player_4_7_2'),
#  (0.0, 'player_4_7_19'),
#  (0.0, 'player_4_7_18'),
#  (0.0, 'player_4_7_17'),
#  (0.0, 'player_4_7_16'),
#  (0.0, 'player_4_7_14'),
#  (0.0, 'player_4_7_13'),
#  (0.0, 'player_4_7_12'),
#  (0.0, 'player_4_7_11'),
#  (0.0, 'player_4_6_9'),
#  (0.0, 'player_4_6_8'),
#  (0.0, 'player_4_6_6'),
#  (0.0, 'player_4_6_4'),
#  (0.0, 'player_4_6_3'),
#  (0.0, 'player_4_6_16'),
#  (0.0, 'player_4_6_15'),
#  (0.0, 'player_4_6_14'),
#  (0.0, 'player_4_6_13'),
#  (0.0, 'player_4_6_12'),
#  (0.0, 'player_4_6_11'),
#  (0.0, 'player_4_6_10'),
#  (0.0, 'player_4_5_9'),
#  (0.0, 'player_4_5_7'),
#  (0.0, 'player_4_5_6'),
#  (0.0, 'player_4_5_5'),
#  (0.0, 'player_4_5_2'),
#  (0.0, 'player_4_5_13'),
#  (0.0, 'player_4_5_12'),
#  (0.0, 'player_4_5_11'),
#  (0.0, 'player_4_5_10'),
#  (0.0, 'player_4_5_1'),
#  (0.0, 'player_4_4_8'),
#  (0.0, 'player_4_4_7'),
#  (0.0, 'player_4_4_6'),
#  (0.0, 'player_4_4_4'),
#  (0.0, 'player_4_4_3'),
#  (0.0, 'player_4_4_2'),
#  (0.0, 'player_4_4_10'),
#  (0.0, 'player_4_4_1'),
#  (0.0, 'player_4_4_0'),
#  (0.0, 'player_4_3_9'),
#  (0.0, 'player_4_3_8'),
#  (0.0, 'player_4_3_7'),
#  (0.0, 'player_4_3_6'),
#  (0.0, 'player_4_3_5'),
#  (0.0, 'player_4_3_4'),
#  (0.0, 'player_4_3_2'),
#  (0.0, 'player_4_3_1'),
#  (0.0, 'player_4_3_0'),
#  (0.0, 'player_4_2_6'),
#  (0.0, 'player_4_2_4'),
#  (0.0, 'player_4_2_3_R_W'),
#  (0.0, 'player_4_2_3_R_S'),
#  (0.0, 'player_4_2_3_R_O'),
#  (0.0, 'player_4_2_3_R_L'),
#  (0.0, 'player_4_2_3_R_C'),
#  (0.0, 'player_4_2_3_R_3G'),
#  (0.0, 'player_4_2_3_R_2W'),
#  (0.0, 'player_4_2_3_R_2S'),
#  (0.0, 'player_4_2_3_P_4'),
#  (0.0, 'player_4_2_3_P_1'),
#  (0.0, 'player_4_2_3_P_0'),
#  (0.0, 'player_4_2_3_N_9'),
#  (0.0, 'player_4_2_3_N_5'),
#  (0.0, 'player_4_2_3_N_3'),
#  (0.0, 'player_4_2_3_N_2'),
#  (0.0, 'player_4_2_3_N_10'),
#  (0.0, 'player_4_2_3_N_0'),
#  (0.0, 'player_4_2_3'),
#  (0.0, 'player_4_2_2_R_S'),
#  (0.0, 'player_4_2_2_R_O'),
#  (0.0, 'player_4_2_2_R_L'),
#  (0.0, 'player_4_2_2_R_C'),
#  (0.0, 'player_4_2_2_P_4'),
#  (0.0, 'player_4_2_2_P_3'),
#  (0.0, 'player_4_2_2_P_2'),
#  (0.0, 'player_4_2_2_P_1'),
#  (0.0, 'player_4_2_2_N_9'),
#  (0.0, 'player_4_2_2_N_6'),
#  (0.0, 'player_4_2_2_N_5'),
#  (0.0, 'player_4_2_2_N_4'),
#  (0.0, 'player_4_2_2_N_3'),
#  (0.0, 'player_4_2_2_N_2'),
#  (0.0, 'player_4_2_2_N_10'),
#  (0.0, 'player_4_2_2'),
#  (0.0, 'player_4_2_1_R_W'),
#  (0.0, 'player_4_2_1_R_S'),
#  (0.0, 'player_4_2_1_R_O'),
#  (0.0, 'player_4_2_1_R_L'),
#  (0.0, 'player_4_2_1_R_C'),
#  (0.0, 'player_4_2_1_P_5'),
#  (0.0, 'player_4_2_1_P_2'),
#  (0.0, 'player_4_2_1_N_9'),
#  (0.0, 'player_4_2_1_N_8'),
#  (0.0, 'player_4_2_1_N_6'),
#  (0.0, 'player_4_2_1_N_5'),
#  (0.0, 'player_4_2_1_N_3'),
#  (0.0, 'player_4_2_1'),
#  (0.0, 'player_4_2_0'),
#  (0.0, 'player_4_1_3_R_W'),
#  (0.0, 'player_4_1_3_R_S'),
#  (0.0, 'player_4_1_3_R_O'),
#  (0.0, 'player_4_1_3_R_D'),
#  (0.0, 'player_4_1_3_R_C'),
#  (0.0, 'player_4_1_3_R_3G'),
#  (0.0, 'player_4_1_3_R_2W'),
#  (0.0, 'player_4_1_3_R_2S'),
#  (0.0, 'player_4_1_3_R_2L'),
#  (0.0, 'player_4_1_3_P_4'),
#  (0.0, 'player_4_1_3_P_3'),
#  (0.0, 'player_4_1_3_P_2'),
#  (0.0, 'player_4_1_3_P_1'),
#  (0.0, 'player_4_1_3_P_0'),
#  (0.0, 'player_4_1_3_N_9'),
#  (0.0, 'player_4_1_3_N_4'),
#  (0.0, 'player_4_1_3_N_12'),
#  (0.0, 'player_4_1_3_N_11'),
#  (0.0, 'player_4_1_3_N_10'),
#  (0.0, 'player_4_1_3_N_0'),
#  (0.0, 'player_4_1_2_R_W'),
#  (0.0, 'player_4_1_2_R_S'),
#  (0.0, 'player_4_1_2_R_O'),
#  (0.0, 'player_4_1_2_R_L'),
#  (0.0, 'player_4_1_2_R_C'),
#  (0.0, 'player_4_1_2_P_5'),
#  (0.0, 'player_4_1_2_P_4'),
#  (0.0, 'player_4_1_2_P_2'),
#  (0.0, 'player_4_1_2_P_1'),
#  (0.0, 'player_4_1_2_N_9'),
#  (0.0, 'player_4_1_2_N_8'),
#  (0.0, 'player_4_1_2_N_6'),
#  (0.0, 'player_4_1_2_N_5'),
#  (0.0, 'player_4_1_2_N_4'),
#  (0.0, 'player_4_1_2_N_3'),
#  (0.0, 'player_4_1_2_N_2'),
#  (0.0, 'player_4_1_2_N_11'),
#  (0.0, 'player_4_1_2_N_10'),
#  (0.0, 'player_4_1_1_R_W'),
#  (0.0, 'player_4_1_1_R_S'),
#  (0.0, 'player_4_1_1_R_L'),
#  (0.0, 'player_4_1_1_R_C'),
#  (0.0, 'player_4_1_1_P_4'),
#  (0.0, 'player_4_1_1_P_3'),
#  (0.0, 'player_4_1_1_P_2'),
#  (0.0, 'player_4_1_1_N_9'),
#  (0.0, 'player_4_1_1_N_8'),
#  (0.0, 'player_4_1_1_N_6'),
#  (0.0, 'player_4_1_1_N_5'),
#  (0.0, 'player_4_1_1_N_4'),
#  (0.0, 'player_4_1_1_N_3'),
#  (0.0, 'player_4_12_7'),
#  (0.0, 'player_4_12_5'),
#  (0.0, 'player_4_12_4'),
#  (0.0, 'player_4_12_3'),
#  (0.0, 'player_4_12_2'),
#  (0.0, 'player_4_12_1'),
#  (0.0, 'player_4_12_0'),
#  (0.0, 'player_4_11_8'),
#  (0.0, 'player_4_11_7'),
#  (0.0, 'player_4_11_6'),
#  (0.0, 'player_4_11_5'),
#  (0.0, 'player_4_11_3'),
#  (0.0, 'player_4_11_2'),
#  (0.0, 'player_4_11_1'),
#  (0.0, 'player_4_10_9'),
#  (0.0, 'player_4_10_8'),
#  (0.0, 'player_4_10_7'),
#  (0.0, 'player_4_10_6'),
#  (0.0, 'player_4_10_5'),
#  (0.0, 'player_4_10_4'),
#  (0.0, 'player_4_10_2'),
#  (0.0, 'player_4_10_11'),
#  (0.0, 'player_4_10_10'),
#  (0.0, 'player_4_10_1'),
#  (0.0, 'player_3_win_1'),
#  (0.0, 'player_3_tribute_9'),
#  (0.0, 'player_3_tribute_8'),
#  (0.0, 'player_3_tribute_5'),
#  (0.0, 'player_3_tribute_4'),
#  (0.0, 'player_3_tribute_16'),
#  (0.0, 'player_3_tribute_13'),
#  (0.0, 'player_3_tribute_12'),
#  (0.0, 'player_3_tribute_10'),
#  (0.0, 'player_3_tribute_0'),
#  (0.0, 'player_3_tradeLoss_9'),
#  (0.0, 'player_3_tradeLoss_8'),
#  (0.0, 'player_3_tradeLoss_7'),
#  (0.0, 'player_3_tradeLoss_6'),
#  (0.0, 'player_3_tradeLoss_5'),
#  (0.0, 'player_3_tradeLoss_47'),
#  (0.0, 'player_3_tradeLoss_4'),
#  (0.0, 'player_3_tradeLoss_37'),
#  (0.0, 'player_3_tradeLoss_34'),
#  (0.0, 'player_3_tradeLoss_33'),
#  (0.0, 'player_3_tradeLoss_32'),
#  (0.0, 'player_3_tradeLoss_30'),
#  (0.0, 'player_3_tradeLoss_28'),
#  (0.0, 'player_3_tradeLoss_26'),
#  (0.0, 'player_3_tradeLoss_25'),
#  (0.0, 'player_3_tradeLoss_23'),
#  (0.0, 'player_3_tradeLoss_22'),
#  (0.0, 'player_3_tradeLoss_20'),
#  (0.0, 'player_3_tradeLoss_18'),
#  (0.0, 'player_3_tradeLoss_17'),
#  (0.0, 'player_3_tradeLoss_16'),
#  (0.0, 'player_3_tradeLoss_15'),
#  (0.0, 'player_3_tradeLoss_14'),
#  (0.0, 'player_3_tradeLoss_13'),
#  (0.0, 'player_3_tradeLoss_12'),
#  (0.0, 'player_3_tradeLoss_11'),
#  (0.0, 'player_3_tradeLoss_10'),
#  (0.0, 'player_3_tradeGain_9'),
#  (0.0, 'player_3_tradeGain_8'),
#  (0.0, 'player_3_tradeGain_7'),
#  (0.0, 'player_3_tradeGain_6'),
#  (0.0, 'player_3_tradeGain_5'),
#  (0.0, 'player_3_tradeGain_4'),
#  (0.0, 'player_3_tradeGain_3'),
#  (0.0, 'player_3_tradeGain_2'),
#  (0.0, 'player_3_tradeGain_19'),
#  (0.0, 'player_3_tradeGain_18'),
#  (0.0, 'player_3_tradeGain_17'),
#  (0.0, 'player_3_tradeGain_13'),
#  (0.0, 'player_3_tradeGain_12'),
#  (0.0, 'player_3_tradeGain_11'),
#  (0.0, 'player_3_tradeGain_10'),
#  (0.0, 'player_3_tradeGain_1'),
#  (0.0, 'player_3_totalLoss_9'),
#  (0.0, 'player_3_totalLoss_8'),
#  (0.0, 'player_3_totalLoss_59'),
#  (0.0, 'player_3_totalLoss_56'),
#  (0.0, 'player_3_totalLoss_46'),
#  (0.0, 'player_3_totalLoss_45'),
#  (0.0, 'player_3_totalLoss_44'),
#  (0.0, 'player_3_totalLoss_42'),
#  (0.0, 'player_3_totalLoss_41'),
#  (0.0, 'player_3_totalLoss_40'),
#  (0.0, 'player_3_totalLoss_39'),
#  (0.0, 'player_3_totalLoss_38'),
#  (0.0, 'player_3_totalLoss_37'),
#  (0.0, 'player_3_totalLoss_34'),
#  (0.0, 'player_3_totalLoss_32'),
#  (0.0, 'player_3_totalLoss_31'),
#  (0.0, 'player_3_totalLoss_27'),
#  (0.0, 'player_3_totalLoss_26'),
#  (0.0, 'player_3_totalLoss_25'),
#  (0.0, 'player_3_totalLoss_23'),
#  (0.0, 'player_3_totalLoss_22'),
#  (0.0, 'player_3_totalLoss_21'),
#  (0.0, 'player_3_totalLoss_20'),
#  (0.0, 'player_3_totalLoss_19'),
#  (0.0, 'player_3_totalLoss_18'),
#  (0.0, 'player_3_totalLoss_17'),
#  (0.0, 'player_3_totalLoss_15'),
#  (0.0, 'player_3_totalLoss_14'),
#  (0.0, 'player_3_totalLoss_13'),
#  (0.0, 'player_3_totalLoss_12'),
#  (0.0, 'player_3_totalLoss_11'),
#  (0.0, 'player_3_totalLoss_10'),
#  (0.0, 'player_3_totalGain_93'),
#  (0.0, 'player_3_totalGain_92'),
#  (0.0, 'player_3_totalGain_91'),
#  (0.0, 'player_3_totalGain_90'),
#  (0.0, 'player_3_totalGain_88'),
#  (0.0, 'player_3_totalGain_87'),
#  (0.0, 'player_3_totalGain_86'),
#  (0.0, 'player_3_totalGain_85'),
#  (0.0, 'player_3_totalGain_82'),
#  (0.0, 'player_3_totalGain_80'),
#  (0.0, 'player_3_totalGain_79'),
#  (0.0, 'player_3_totalGain_75'),
#  (0.0, 'player_3_totalGain_68'),
#  (0.0, 'player_3_totalGain_66'),
#  (0.0, 'player_3_totalGain_65'),
#  (0.0, 'player_3_totalGain_62'),
#  (0.0, 'player_3_totalGain_61'),
#  (0.0, 'player_3_totalGain_59'),
#  (0.0, 'player_3_totalGain_58'),
#  (0.0, 'player_3_totalGain_55'),
#  (0.0, 'player_3_totalGain_54'),
#  (0.0, 'player_3_totalGain_53'),
#  (0.0, 'player_3_totalGain_48'),
#  (0.0, 'player_3_totalGain_46'),
#  (0.0, 'player_3_totalGain_45'),
#  (0.0, 'player_3_totalGain_43'),
#  (0.0, 'player_3_totalGain_39'),
#  (0.0, 'player_3_totalGain_38'),
#  (0.0, 'player_3_totalGain_36'),
#  (0.0, 'player_3_totalGain_35'),
#  (0.0, 'player_3_totalGain_34'),
#  (0.0, 'player_3_totalGain_25'),
#  (0.0, 'player_3_totalGain_23'),
#  (0.0, 'player_3_totalGain_115'),
#  (0.0, 'player_3_totalGain_105'),
#  (0.0, 'player_3_totalGain_103'),
#  (0.0, 'player_3_totalAvailable_8'),
#  (0.0, 'player_3_totalAvailable_59'),
#  (0.0, 'player_3_totalAvailable_56'),
#  (0.0, 'player_3_totalAvailable_53'),
#  (0.0, 'player_3_totalAvailable_52'),
#  (0.0, 'player_3_totalAvailable_51'),
#  (0.0, 'player_3_totalAvailable_50'),
#  (0.0, 'player_3_totalAvailable_49'),
#  (0.0, 'player_3_totalAvailable_48'),
#  (0.0, 'player_3_totalAvailable_47'),
#  (0.0, 'player_3_totalAvailable_46'),
#  (0.0, 'player_3_totalAvailable_45'),
#  (0.0, 'player_3_totalAvailable_44'),
#  (0.0, 'player_3_totalAvailable_43'),
#  (0.0, 'player_3_totalAvailable_42'),
#  (0.0, 'player_3_totalAvailable_41'),
#  (0.0, 'player_3_totalAvailable_40'),
#  (0.0, 'player_3_totalAvailable_36'),
#  (0.0, 'player_3_totalAvailable_35'),
#  (0.0, 'player_3_totalAvailable_33'),
#  (0.0, 'player_3_totalAvailable_32'),
#  (0.0, 'player_3_totalAvailable_31'),
#  (0.0, 'player_3_totalAvailable_30'),
#  (0.0, 'player_3_totalAvailable_29'),
#  (0.0, 'player_3_totalAvailable_28'),
#  (0.0, 'player_3_totalAvailable_27'),
#  (0.0, 'player_3_totalAvailable_26'),
#  (0.0, 'player_3_totalAvailable_24'),
#  (0.0, 'player_3_totalAvailable_23'),
#  (0.0, 'player_3_totalAvailable_22'),
#  (0.0, 'player_3_totalAvailable_21'),
#  (0.0, 'player_3_totalAvailable_14'),
#  (0.0, 'player_3_robberCardsLoss_9'),
#  (0.0, 'player_3_robberCardsLoss_8'),
#  (0.0, 'player_3_robberCardsLoss_7'),
#  (0.0, 'player_3_robberCardsLoss_6'),
#  (0.0, 'player_3_robberCardsLoss_5'),
#  (0.0, 'player_3_robberCardsLoss_3'),
#  (0.0, 'player_3_robberCardsLoss_21'),
#  (0.0, 'player_3_robberCardsLoss_2'),
#  (0.0, 'player_3_robberCardsLoss_16'),
#  (0.0, 'player_3_robberCardsLoss_13'),
#  (0.0, 'player_3_robberCardsLoss_12'),
#  (0.0, 'player_3_robberCardsLoss_11'),
#  (0.0, 'player_3_robberCardsLoss_10'),
#  (0.0, 'player_3_robberCardsLoss_1'),
#  (0.0, 'player_3_robberCardsLoss_0'),
#  (0.0, 'player_3_robberCardsGain_8'),
#  (0.0, 'player_3_robberCardsGain_7'),
#  (0.0, 'player_3_robberCardsGain_6'),
#  (0.0, 'player_3_robberCardsGain_5'),
#  (0.0, 'player_3_robberCardsGain_4'),
#  (0.0, 'player_3_robberCardsGain_3'),
#  (0.0, 'player_3_robberCardsGain_20'),
#  (0.0, 'player_3_robberCardsGain_17'),
#  (0.0, 'player_3_robberCardsGain_16'),
#  (0.0, 'player_3_robberCardsGain_15'),
#  (0.0, 'player_3_robberCardsGain_14'),
#  (0.0, 'player_3_robberCardsGain_12'),
#  (0.0, 'player_3_robberCardsGain_10'),
#  (0.0, 'player_3_robberCardsGain_1'),
#  (0.0, 'player_3_robberCardsGain_0'),
#  (0.0, 'player_3_production_92'),
#  (0.0, 'player_3_production_83'),
#  (0.0, 'player_3_production_79'),
#  (0.0, 'player_3_production_77'),
#  (0.0, 'player_3_production_75'),
#  (0.0, 'player_3_production_72'),
#  (0.0, 'player_3_production_71'),
#  (0.0, 'player_3_production_70'),
#  (0.0, 'player_3_production_65'),
#  (0.0, 'player_3_production_64'),
#  (0.0, 'player_3_production_63'),
#  (0.0, 'player_3_production_62'),
#  (0.0, 'player_3_production_61'),
#  (0.0, 'player_3_production_60'),
#  (0.0, 'player_3_production_59'),
#  (0.0, 'player_3_production_56'),
#  (0.0, 'player_3_production_54'),
#  (0.0, 'player_3_production_52'),
#  (0.0, 'player_3_production_50'),
#  (0.0, 'player_3_production_47'),
#  (0.0, 'player_3_production_46'),
#  (0.0, 'player_3_production_43'),
#  (0.0, 'player_3_production_41'),
#  (0.0, 'player_3_production_39'),
#  (0.0, 'player_3_production_37'),
#  (0.0, 'player_3_production_35'),
#  (0.0, 'player_3_production_34'),
#  (0.0, 'player_3_production_31'),
#  (0.0, 'player_3_production_30'),
#  (0.0, 'player_3_production_29'),
#  (0.0, 'player_3_production_26'),
#  (0.0, 'player_3_production_25'),
#  (0.0, 'player_3_production_19'),
#  (0.0, 'player_3_points_9'),
#  (0.0, 'player_3_points_8'),
#  (0.0, 'player_3_points_7'),
#  (0.0, 'player_3_points_6'),
#  (0.0, 'player_3_points_5'),
#  (0.0, 'player_3_points_4'),
#  (0.0, 'player_3_points_3'),
#  (0.0, 'player_3_points_11'),
#  (0.0, 'player_3_me_1'),
#  (0.0, 'player_3_me_'),
#  (0.0, 'player_3_9_9'),
#  (0.0, 'player_3_9_8'),
#  (0.0, 'player_3_9_6'),
#  (0.0, 'player_3_9_5'),
#  (0.0, 'player_3_9_4'),
#  (0.0, 'player_3_9_3'),
#  (0.0, 'player_3_9_15'),
#  (0.0, 'player_3_9_14'),
#  (0.0, 'player_3_9_11'),
#  (0.0, 'player_3_9_10'),
#  (0.0, 'player_3_8_9'),
#  (0.0, 'player_3_8_8'),
#  (0.0, 'player_3_8_7'),
#  (0.0, 'player_3_8_5'),
#  (0.0, 'player_3_8_4'),
#  (0.0, 'player_3_8_18'),
#  (0.0, 'player_3_8_16'),
#  (0.0, 'player_3_8_14'),
#  (0.0, 'player_3_8_13'),
#  (0.0, 'player_3_8_12'),
#  (0.0, 'player_3_8_11'),
#  (0.0, 'player_3_8_10'),
#  (0.0, 'player_3_7_9'),
#  (0.0, 'player_3_7_8'),
#  (0.0, 'player_3_7_7'),
#  (0.0, 'player_3_7_6'),
#  (0.0, 'player_3_7_5'),
#  (0.0, 'player_3_7_4'),
#  (0.0, 'player_3_7_23'),
#  (0.0, 'player_3_7_20'),
#  (0.0, 'player_3_7_2'),
#  (0.0, 'player_3_7_19'),
#  (0.0, 'player_3_7_18'),
#  (0.0, 'player_3_7_17'),
#  (0.0, 'player_3_7_16'),
#  (0.0, 'player_3_7_14'),
#  (0.0, 'player_3_7_13'),
#  (0.0, 'player_3_7_12'),
#  (0.0, 'player_3_7_11'),
#  (0.0, 'player_3_6_9'),
#  (0.0, 'player_3_6_8'),
#  (0.0, 'player_3_6_6'),
#  (0.0, 'player_3_6_5'),
#  (0.0, 'player_3_6_4'),
#  (0.0, 'player_3_6_3'),
#  (0.0, 'player_3_6_16'),
#  (0.0, 'player_3_6_15'),
#  (0.0, 'player_3_6_14'),
#  (0.0, 'player_3_6_13'),
#  (0.0, 'player_3_6_12'),
#  (0.0, 'player_3_6_11'),
#  (0.0, 'player_3_6_10'),
#  (0.0, 'player_3_5_9'),
#  (0.0, 'player_3_5_6'),
#  (0.0, 'player_3_5_5'),
#  (0.0, 'player_3_5_2'),
#  (0.0, 'player_3_5_13'),
#  (0.0, 'player_3_5_12'),
#  (0.0, 'player_3_5_11'),
#  (0.0, 'player_3_5_10'),
#  (0.0, 'player_3_5_1'),
#  (0.0, 'player_3_4_8'),
#  (0.0, 'player_3_4_7'),
#  (0.0, 'player_3_4_6'),
#  (0.0, 'player_3_4_4'),
#  (0.0, 'player_3_4_3'),
#  (0.0, 'player_3_4_2'),
#  (0.0, 'player_3_4_10'),
#  (0.0, 'player_3_4_1'),
#  (0.0, 'player_3_4_0'),
#  (0.0, 'player_3_3_9'),
#  (0.0, 'player_3_3_8'),
#  (0.0, 'player_3_3_7'),
#  (0.0, 'player_3_3_6'),
#  (0.0, 'player_3_3_5'),
#  (0.0, 'player_3_3_4'),
#  (0.0, 'player_3_3_1'),
#  (0.0, 'player_3_3_0'),
#  (0.0, 'player_3_2_6'),
#  (0.0, 'player_3_2_4'),
#  (0.0, 'player_3_2_3_R_W'),
#  (0.0, 'player_3_2_3_R_S'),
#  (0.0, 'player_3_2_3_R_O'),
#  (0.0, 'player_3_2_3_R_L'),
#  (0.0, 'player_3_2_3_R_D'),
#  (0.0, 'player_3_2_3_R_C'),
#  (0.0, 'player_3_2_3_R_B'),
#  (0.0, 'player_3_2_3_R_3G'),
#  (0.0, 'player_3_2_3_R_2W'),
#  (0.0, 'player_3_2_3_R_2S'),
#  (0.0, 'player_3_2_3_R_2O'),
#  (0.0, 'player_3_2_3_R_2L'),
#  (0.0, 'player_3_2_3_R_2C'),
#  (0.0, 'player_3_2_3_P_3'),
#  (0.0, 'player_3_2_3_P_2'),
#  (0.0, 'player_3_2_3_P_1'),
#  (0.0, 'player_3_2_3_P_0'),
#  (0.0, 'player_3_2_3_N_2'),
#  (0.0, 'player_3_2_3_N_12'),
#  (0.0, 'player_3_2_3_N_11'),
#  (0.0, 'player_3_2_3_N_10'),
#  (0.0, 'player_3_2_3_N_0'),
#  (0.0, 'player_3_2_3'),
#  (0.0, 'player_3_2_2_R_W'),
#  (0.0, 'player_3_2_2_R_S'),
#  (0.0, 'player_3_2_2_R_O'),
#  (0.0, 'player_3_2_2_R_L'),
#  (0.0, 'player_3_2_2_R_C'),
#  (0.0, 'player_3_2_2_P_5'),
#  (0.0, 'player_3_2_2_P_4'),
#  (0.0, 'player_3_2_2_P_3'),
#  (0.0, 'player_3_2_2_P_2'),
#  (0.0, 'player_3_2_2_P_1'),
#  (0.0, 'player_3_2_2_N_8'),
#  (0.0, 'player_3_2_2_N_6'),
#  (0.0, 'player_3_2_2_N_5'),
#  (0.0, 'player_3_2_2_N_3'),
#  (0.0, 'player_3_2_2_N_2'),
#  (0.0, 'player_3_2_2_N_11'),
#  (0.0, 'player_3_2_2_N_10'),
#  (0.0, 'player_3_2_2'),
#  (0.0, 'player_3_2_1_R_W'),
#  (0.0, 'player_3_2_1_R_S'),
#  (0.0, 'player_3_2_1_R_O'),
#  (0.0, 'player_3_2_1_R_L'),
#  (0.0, 'player_3_2_1_R_C'),
#  (0.0, 'player_3_2_1_P_4'),
#  (0.0, 'player_3_2_1_P_3'),
#  (0.0, 'player_3_2_1_P_2'),
#  (0.0, 'player_3_2_1_N_9'),
#  (0.0, 'player_3_2_1_N_6'),
#  (0.0, 'player_3_2_1_N_5'),
#  (0.0, 'player_3_2_1_N_4'),
#  (0.0, 'player_3_2_1_N_3'),
#  (0.0, 'player_3_2_1'),
#  (0.0, 'player_3_2_0'),
#  (0.0, 'player_3_1_3_R_S'),
#  (0.0, 'player_3_1_3_R_O'),
#  (0.0, 'player_3_1_3_R_L'),
#  (0.0, 'player_3_1_3_R_C'),
#  (0.0, 'player_3_1_3_R_2S'),
#  (0.0, 'player_3_1_3_P_4'),
#  (0.0, 'player_3_1_3_P_3'),
#  (0.0, 'player_3_1_3_P_2'),
#  (0.0, 'player_3_1_3_P_0'),
#  (0.0, 'player_3_1_3_N_9'),
#  (0.0, 'player_3_1_3_N_3'),
#  (0.0, 'player_3_1_3_N_2'),
#  (0.0, 'player_3_1_3_N_11'),
#  (0.0, 'player_3_1_3_N_10'),
#  (0.0, 'player_3_1_3_N_0'),
#  (0.0, 'player_3_1_2_R_W'),
#  (0.0, 'player_3_1_2_R_O'),
#  (0.0, 'player_3_1_2_R_L'),
#  (0.0, 'player_3_1_2_R_C'),
#  (0.0, 'player_3_1_2_P_5'),
#  (0.0, 'player_3_1_2_P_4'),
#  (0.0, 'player_3_1_2_N_9'),
#  (0.0, 'player_3_1_2_N_8'),
#  (0.0, 'player_3_1_2_N_6'),
#  (0.0, 'player_3_1_2_N_4'),
#  (0.0, 'player_3_1_2_N_10'),
#  (0.0, 'player_3_1_1_R_W'),
#  (0.0, 'player_3_1_1_R_S'),
#  (0.0, 'player_3_1_1_R_O'),
#  (0.0, 'player_3_1_1_R_L'),
#  (0.0, 'player_3_1_1_R_C'),
#  (0.0, 'player_3_1_1_P_5'),
#  (0.0, 'player_3_1_1_P_4'),
#  (0.0, 'player_3_1_1_P_3'),
#  (0.0, 'player_3_1_1_N_9'),
#  (0.0, 'player_3_1_1_N_6'),
#  (0.0, 'player_3_1_1_N_5'),
#  (0.0, 'player_3_1_1_N_4'),
#  (0.0, 'player_3_12_7'),
#  (0.0, 'player_3_12_5'),
#  (0.0, 'player_3_12_4'),
#  (0.0, 'player_3_12_3'),
#  (0.0, 'player_3_12_2'),
#  (0.0, 'player_3_12_1'),
#  (0.0, 'player_3_12_0'),
#  (0.0, 'player_3_11_8'),
#  (0.0, 'player_3_11_7'),
#  (0.0, 'player_3_11_6'),
#  (0.0, 'player_3_11_5'),
#  (0.0, 'player_3_11_3'),
#  (0.0, 'player_3_11_2'),
#  (0.0, 'player_3_11_1'),
#  (0.0, 'player_3_11_0'),
#  (0.0, 'player_3_10_9'),
#  (0.0, 'player_3_10_8'),
#  (0.0, 'player_3_10_7'),
#  (0.0, 'player_3_10_6'),
#  (0.0, 'player_3_10_5'),
#  (0.0, 'player_3_10_4'),
#  (0.0, 'player_3_10_2'),
#  (0.0, 'player_3_10_11'),
#  (0.0, 'player_3_10_10'),
#  (0.0, 'player_3_10_1'),
#  (0.0, 'player_2_win_1'),
#  (0.0, 'player_2_win_0'),
#  (0.0, 'player_2_tribute_9'),
#  (0.0, 'player_2_tribute_5'),
#  (0.0, 'player_2_tribute_4'),
#  (0.0, 'player_2_tribute_30'),
#  (0.0, 'player_2_tribute_16'),
#  (0.0, 'player_2_tribute_13'),
#  (0.0, 'player_2_tribute_12'),
#  (0.0, 'player_2_tribute_10'),
#  (0.0, 'player_2_tradeLoss_9'),
#  (0.0, 'player_2_tradeLoss_8'),
#  (0.0, 'player_2_tradeLoss_7'),
#  (0.0, 'player_2_tradeLoss_47'),
#  (0.0, 'player_2_tradeLoss_39'),
#  ...]

# %%
# Assign X (data) and y (target)
X = data[columns]
y = data['win'].values.reshape(-1,1)
print(X.shape, y.shape)

# %%
# Split the data into training and testing

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
### END SOLUTION

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

### BEGIN SOLUTION
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
### END SOLUTION

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=2))
model.add(Dense(units=2, activation='softmax'))

### END SOLUTION

# %%
# Create a LinearRegression model and fit it to the scaled training data

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
### END SOLUTION

# %%
# Make predictions using a fitted model
# Plot the difference between the model predicted values and actual y values, versus the model predicted values
# Hint: You can predict values of X training and testing data using the model.predict() method on a fitted model

### BEGIN SOLUTION
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()
### END SOLUTION

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

### BEGIN SOLUTION
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

### BEGIN SOLUTION
lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")

# %%
########################
# GridSearch Estimator #
########################

# %%
data

# %%
data[]
